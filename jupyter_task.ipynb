# %% [markdown]
# # Jupyter Notebook Practice
# *By Thanuja G R*
#
# ---
#
# ## Introduction
# This notebook demonstrates my understanding of **Markdown** and **Python coding** in Jupyter.

# %% [markdown]
#  ## My Learning Goals
#
# - Learn how to create professional Jupyter notebooks
# - Improve my Python coding and visualization skills
# - Understand how to combine code, text, and visuals effectively

# %% [markdown]
# **This text is bold**
# *This text is italicized*
#
# ---
#
# The line above is a horizontal rule!

# %% [markdown]
# ## Image Example
# Here is an image embedded into the notebook:
#
# ![Jupyter Logo](https://raw.githubusercontent.com/Thanu-cpu/Marvel-level-0-report/d6dbad9801d3e9775ca3657fcf263abe14b1e0bf/WhatsApp%20Image%202025-09-14%20at%2010.02.53%20AM.jpeg)

# %% [markdown]
# ## Code Snippet Example
# Here is a simple Python code snippet:
#
# ```python
# x = 5
# y = 10
# print("Sum:", x + y)

# %%
# Simple Calculation
a = 15
b = 10
result = a + b
print("The sum of a and b is:", result)
# Out:
# The sum of a and b is: 25

# %%
import matplotlib.pyplot as plt

# Data for the line plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.title("Simple Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary
# In this notebook, I practiced:
# - Structuring a notebook using Markdown
# - Performing basic Python calculations
# - Creating a simple line plot with **Matplotlib**
#
# This task helped me understand how to **combine code and storytelling** effectively in Jupyter notebooks.
